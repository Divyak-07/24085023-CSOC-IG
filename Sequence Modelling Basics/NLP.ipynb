# %%
import pandas as pd

# %% [markdown]
# Text Pre-Processing

# %%
import pandas as pd
col_names = ["polarity", "title", "text"]

try:
    train = pd.read_csv('/train.csv', engine='python', on_bad_lines='skip',header=None,names=col_names)
    print("Files loaded successfully!")
except pd.errors.ParserError as e:
    print(f"ParserError still occurred: {e}")
    print("Consider inspecting the train.csv file manually around row 126128.")
# Out:
# Files loaded successfully!

# %%
col_names = ["polarity", "title", "text"]

try:
    test = pd.read_csv('/test.csv', engine='python', on_bad_lines='skip',header=None,names=col_names)
    print("Files loaded successfully!")
except pd.errors.ParserError as e:
    print(f"ParserError still occurred: {e}")
    print("Consider inspecting the train.csv file manually around row 126128.")
# Out:
# Files loaded successfully!

# %%
train.head()
# Out:
#    polarity                                              title  \
# 0         2                     Stuning even for the non-gamer
# 1         2              The best soundtrack ever to anything.
# 2         2                                           Amazing!
# 3         2                               Excellent Soundtrack
# 4         2  Remember, Pull Your Jaw Off The Floor After He...
#
#                                                 text
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...

# %%
test.head()
# Out:
#    polarity                                              title  \
# 0         2                                           Great CD
# 1         2  One of the best game music soundtracks - for a...
# 2         1                   Batteries died within a year ...
# 3         2              works fine, but Maha Energy is better
# 4         2                       Great for the non-audiophile
#
#                                                 text
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
# 2  I bought this charger in Jul 2003 and it worke...
# 3  Check out Maha Energy's website. Their Powerex...
# 4  Reviewed quite a bit of the combo players and ...

# %%
print("Train DataFrame columns:", train.columns)
print("Test DataFrame columns:", test.columns)
# Out:
# Train DataFrame columns: Index(['polarity', 'title', 'text'], dtype='object')
# Test DataFrame columns: Index(['polarity', 'title', 'text'], dtype='object')

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def preprocess_text(text):
  # Remove HTML tags
    text = re.sub('<[^>]*>', '', text)

    # Remove non-alphabetic characters and convert to lowercase
    text = re.sub('[^a-zA-Z]', ' ', text).lower()

    # Tokenize the text
    words = word_tokenize(text)

    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Lemmatize the words
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]

    # Combine words back into a single string
    preprocessed_text = ' '.join(words)

    return preprocessed_text

# %%
train['title'] = train['title'].astype(str)
test['title'] = test['title'].astype(str)
train['preprocessed_title'] = train['title'].apply(preprocess_text)
test['preprocessed_title'] = test['title'].apply(preprocess_text)

# %%
train['text'] = train['text'].astype(str)
test['text'] = test['text'].astype(str)
train['preprocessed_text'] = train['text'].apply(preprocess_text)
test['preprocessed_text'] = test['text'].apply(preprocess_text)

# %%
train.head()
# Out:
#    polarity                                              title  \
# 0         2                     Stuning even for the non-gamer
# 1         2              The best soundtrack ever to anything.
# 2         2                                           Amazing!
# 3         2                               Excellent Soundtrack
# 4         2  Remember, Pull Your Jaw Off The Floor After He...
#
#                                                 text  \
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...
#
#                 preprocessed_title  \
# 0           stuning even non gamer
# 1    best soundtrack ever anything
# 2                          amazing
# 3             excellent soundtrack
# 4  remember pull jaw floor hearing
#
# ...

# %%
test.head()
# Out:
#    polarity                                              title  \
# 0         2                                           Great CD
# 1         2  One of the best game music soundtracks - for a...
# 2         1                   Batteries died within a year ...
# 3         2              works fine, but Maha Energy is better
# 4         2                       Great for the non-audiophile
#
#                                                 text  \
# 0  My lovely Pat has one of the GREAT voices of h...
# 1  Despite the fact that I have only played a sma...
# 2  I bought this charger in Jul 2003 and it worke...
# 3  Check out Maha Energy's website. Their Powerex...
# 4  Reviewed quite a bit of the combo players and ...
#
#                                 preprocessed_title  \
# 0                                         great cd
# 1  one best game music soundtrack game really play
# 2                         battery died within year
# 3                     work fine maha energy better
# ...

# %%
X_train = train['preprocessed_text']
y_train = train['polarity']
X_test = test['preprocessed_text']
y_test = test['polarity']

# %%
# !pip install gensim

# %%
# !pip install --upgrade gensim

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from gensim.models import Word2Vec

# %%
import gensim.downloader as api

# %%
def get_google_word2vec_embeddings(data):
    # Load the Google News Word2Vec model
    model = api.load("word2vec-google-news-300")

    tokenized_sentences = [sentence.split() for sentence in data]
    embeddings = []

    for sentence in tokenized_sentences:
        sentence_embeddings = []
        for word in sentence:
            if word in model:
                sentence_embeddings.append(model[word])
        if sentence_embeddings:
            embeddings.append(np.mean(sentence_embeddings, axis=0))
        else:
            embeddings.append(np.zeros(300))

    return np.array(embeddings)

# %%
def train_svm_with_google_word2vec(train_data, test_data):
    X_train = get_google_word2vec_embeddings(train_data)
    X_test = get_google_word2vec_embeddings(test_data)

    clf = SVC()
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    return y_pred

# %%
# Google News Word2Vec
y_pred_google_word2vec = train_svm_with_google_word2vec(X_train, X_test)
accuracy_google_word2vec = accuracy_score(y_test, y_pred_google_word2vec)
print(accuracy_google_word2vec)
# Out:
# 0.8373906852692091

# %%
# !pip install tensorflow

# %% [markdown]
# SimpleRNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, f1_score

# %%
# Preparing the data
max_words = 10000
max_len = 100
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(train['preprocessed_text'])


X_train = tokenizer.texts_to_sequences(train['preprocessed_text'])
X_test = tokenizer.texts_to_sequences(test['preprocessed_text'])

X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# Assuming original polarity is {1,2}, we shift to {0,1}
y_train = (train['polarity'] - 1).values    # shape (n_samples,)
y_test  = (test['polarity']  - 1).values    # shape (n_samples,)


# Build the model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128))
model.add(SimpleRNN(64, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=25, batch_size=128, validation_split=0.1,verbose=2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test,verbose=0)

print("Test accuracy:", accuracy)
# predict & threshold
pred_probs  = model.predict(X_test, verbose=0)
pred_labels = (pred_probs > 0.5).astype(int).reshape(-1)

# confusion matrix & F1
cm = confusion_matrix(y_test, pred_labels)
f1 = f1_score(y_test, pred_labels)

print("Confusion Matrix:\n", cm)
print(f"F1 Score: {f1:.4f}")
# Out:
# Epoch 1/25
# 84/84 - 49s - 589ms/step - accuracy: 0.6835 - loss: 0.5850 - val_accuracy: 0.7708 - val_loss: 0.4928
# Epoch 2/25
# 84/84 - 8s - 96ms/step - accuracy: 0.8915 - loss: 0.2693 - val_accuracy: 0.7708 - val_loss: 0.5031
# Epoch 3/25
# 84/84 - 7s - 88ms/step - accuracy: 0.9763 - loss: 0.0818 - val_accuracy: 0.7767 - val_loss: 0.5985
# Epoch 4/25
# 84/84 - 8s - 98ms/step - accuracy: 0.9971 - loss: 0.0184 - val_accuracy: 0.7708 - val_loss: 0.7340
# Epoch 5/25
# 84/84 - 10s - 125ms/step - accuracy: 0.9994 - loss: 0.0059 - val_accuracy: 0.7548 - val_loss: 0.7937
# Epoch 6/25
# 84/84 - 10s - 121ms/step - accuracy: 0.9999 - loss: 0.0028 - val_accuracy: 0.7674 - val_loss: 0.8449
# Epoch 7/25
# 84/84 - 6s - 68ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 0.7699 - val_loss: 0.8825
# Epoch 8/25
# 84/84 - 7s - 83ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.7683 - val_loss: 0.9186
# Epoch 9/25
# ...

# %% [markdown]
# LSTM

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Embedding, SpatialDropout1D, LSTM, Dense, Dropout

# Preparing the data
max_words = 10000
max_len = 100
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(train['preprocessed_text'])

X_train = tokenizer.texts_to_sequences(train['preprocessed_text'])
X_test = tokenizer.texts_to_sequences(test['preprocessed_text'])


X_train = pad_sequences(X_train, padding='post',maxlen=max_len)
X_test = pad_sequences(X_test, padding='post',maxlen=max_len)

y_train = (train['polarity']-1).values
y_test = (test['polarity']-1).values

# Build the model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, mask_zero=True))
model.add(LSTM(64, return_sequences = False, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(64, activation='relu'))
model.add( Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=25, batch_size=128, validation_split=0.1,verbose=2)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test,verbose=0)

print("Test accuracy:", accuracy)

# predict & threshold
pred_probs  = model.predict(X_test, verbose=0)
pred_labels = (pred_probs > 0.5).astype(int).reshape(-1)

# confusion matrix & F1
cm = confusion_matrix(y_test, pred_labels)
f1 = f1_score(y_test, pred_labels)

print("Confusion Matrix:\n", cm)
print(f"F1 Score: {f1:.4f}")
# Out:
# Epoch 1/25
# 84/84 - 30s - 355ms/step - accuracy: 0.7403 - loss: 0.5437 - val_accuracy: 0.8035 - val_loss: 0.4436
# Epoch 2/25
# 84/84 - 22s - 264ms/step - accuracy: 0.8785 - loss: 0.3044 - val_accuracy: 0.8018 - val_loss: 0.4359
# Epoch 3/25
# 84/84 - 24s - 287ms/step - accuracy: 0.9243 - loss: 0.2104 - val_accuracy: 0.7901 - val_loss: 0.5105
# Epoch 4/25
# 84/84 - 45s - 535ms/step - accuracy: 0.9430 - loss: 0.1622 - val_accuracy: 0.7851 - val_loss: 0.5851
# Epoch 5/25
# 84/84 - 39s - 460ms/step - accuracy: 0.9578 - loss: 0.1201 - val_accuracy: 0.7716 - val_loss: 0.6964
# Epoch 6/25
# 84/84 - 24s - 286ms/step - accuracy: 0.9708 - loss: 0.0888 - val_accuracy: 0.7825 - val_loss: 0.8056
# Epoch 7/25
# 84/84 - 22s - 263ms/step - accuracy: 0.9789 - loss: 0.0661 - val_accuracy: 0.7599 - val_loss: 0.8506
# Epoch 8/25
# 84/84 - 41s - 488ms/step - accuracy: 0.9848 - loss: 0.0486 - val_accuracy: 0.7531 - val_loss: 1.0941
# Epoch 9/25
# ...
